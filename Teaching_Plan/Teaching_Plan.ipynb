# %% [markdown]
# # Teaching Plan
# **Theory part: 10–15 min**

# %% [markdown]
# ## Purpose
# - To introduce the basic concept of state machine.
# - To introduce the basic explanation of the Python syntax.
# - To summarize the concept of coding into a more understandable concept.

# %% [markdown]
# ## Content
#
# | Topic | Time (min) |
# |-------|------------|
# | State machine | 5 min |
# | Python example | 10 min |
# | **Total** | **15 min** |

# %% [markdown]
# ---
# ## State Machine
#
# **Definition of state machine:** A model that explains how a system moves through finite states based on given inputs.
#
# The state machine has the following characteristics:
#
# - Has a fixed set of possible states
# - Has a set of inputs that trigger state transitions
# - Has a transition function (State changing)
# - Has a set of possible outputs

# %% [markdown]
# ### Example of State Machine
#
# State Machine can be used in various applications such as:
#
# - Light Switch (On–Off) 💡
# ![](Picture/Screenshot%202026-05-16%20175920.png)
# - Vending machine 🏧
#
# ![](Picture/State_Machine.png)
#
# > *(Briefly explain about diagram and table)*

# %% [markdown]
# ---
# ## Python
#
# ### Reason why to use Python
#
# - The syntax is easy to read and understandable for beginners
# - The program can be used in many different fields such as:
#   - Data Processing
#   - Machine Learning
#   - Deep Learning
#   - Process Serial (Message from microcontroller like Arduino)

# %% [markdown]
# ### Content in Python
#
# Due to the time limit, 5 important topics were selected:
#
# 1. Data type and variable
# 2. Input & Operator
# 3. Logic (if-else)
# 4. Loop *(if there is enough time)*
# 5. State Machine

# %% [markdown]
# ---
# ## Example 1: Data Type and Variable
#
# In a programming language, we have 3 main data types:
#
# - `int` : For whole numbers (e.g. `20`)
# - `float` : For numbers with decimals (e.g. `4.0`)
# - `string` : For any alphabet set (e.g. `"RAI"`)
#
# If we want to display these variables we can use `print()` to display them.
# We can use `f""` to print our data more easily.

# %%
name = "Saipan"   # string
sleep_hr = 8.5    # float
age = 19          # int

print(f"My name is {name}. I am {age} years old. I sleep {sleep_hr} hrs.")
# Out:
# My name is Saipan. I am 19 years old. I sleep 8.5 hrs.

# %% [markdown]
# ---
# ## Example 2: Input & Operator
#
# We can use `input()` to receive data from the user, making our program more interactive.
#
# When we receive data from `input()`, it is returned as a **string**. Therefore, we need to use `int()` or `float()` to convert the data into numerical values that can be used in calculations.
#
# Moreover, we can also perform mathematical operations on numbers:
#
# | Operator | Name | Example |
# |----------|------|---------|
# | `+` | Addition | `x + y` |
# | `-` | Subtraction | `x - y` |
# | `*` | Multiplication | `x * y` |
# | `/` | Division | `x / y` |
# | `%` | Modulus | `x % y` |
# | `**` | Exponentiation | `x ** y` |
# | `//` | Floor division | `x // y` |
#
# > **Note:**
# > - Modulus (`%`) gives the *remainder of a division* — e.g. `3 % 2 = 1`
# > - Floor division (`//`) divides numbers and removes the decimal part.
#
# > *For Teaching: Only briefly explain what types of operators we have, then reference the material book.*

# %% [markdown]
# ### Without `int()` conversion

# %%
# Without int
a = input("Put first number: ")
b = input("Put second number: ")
ans = a + b
print(f"The sum of number a and b is {ans}")
print(f"Type of a: {type(a)} | Type of b: {type(b)}")
# Out:
# The sum of number a and b is 12
# Type of a: <class 'str'> | Type of b: <class 'str'>

# %% [markdown]
# ### With `int()` conversion

# %%
# With int
a = int(input("Put first number: "))
b = int(input("Put second number: "))
ans = a + b
print(f"The sum of number a and b is {ans}")
# Out:
# The sum of number a and b is 3

# %% [markdown]
# ---
# ## Example 3: Logic (If-Else)
#
# Logic or `if-else` is one of the most important topics in Python, especially in state machines, since each state needs a **condition** before going to the next state.
#
# **Logic operations:**
#
# - `>` — more than
# - `<` — less than
# - `==` — equal
# - `!=` — not equal
# - `and` — both conditions must be true
# - `or` — one of the conditions has to be true

# %% [markdown]
# ### Flowchart
#
# ![Flowchart](Picture/2022_07_Python-if…elif…else-Statement-flowchart-.jpg)

# %%
gpa = 2.0

if gpa < 0 or gpa > 4.0:
    print("Invalid Grade")
elif gpa < 1.0:
    print("Status: Retired")
elif gpa < 2.0:
    print("Status: Probation")
else:
    print("Status: Normal")
# Out:
# Status: Normal

# %% [markdown]
# ---
# ## Example 4: Loop
#
# In Python, we have 2 different kinds of loops: `for` and `while`.
#
# We can apply this in state machines to make the state run over and over again until we want to stop.
#
# - **`for` loop** — used for iterating over a sequence (list, tuple, dictionary, set, or string). We can also use `range()` to loop through a set of code a specified number of times. *(Can be useful to check whether our action is valid or not)*
# - **`while` loop** — executes a set of statements as long as a condition is true.
#
# **Loop Diagram**
#
# ![](https://www.codingem.com/wp-content/uploads/2021/09/flowchart-for-loop.003.jpeg)
#
# credit: https://www.codingem.com/flowchart-loop/

# %% [markdown]
# ### While loop

# %%
# While loop
i = 0
while i < 4:
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ### For loop

# %%
# For loop
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ---
# ## Example 5: State Machine Using If-Else
#
# A state machine has:
#
# - a **current state**
# - an **input / action**
# - a **next state**
#
# **Example:** A light switch has two states:
# - Light OFF 💡
# - Light ON 💡
#
# When the user types `"Flip"`, the switch changes state.
#
# We use `if-else` statements to check the input and change to the next state.
# Moreover, we use `while True` to make the program run continuously until the user types `"quit"`, which breaks the loop and ends the program.
#
# ![](Picture/Screenshot%202026-05-16%20175920.png)

# %%
state = "Light OFF"

while True:
    user_input = input("Type 'flip' to switch the light (or 'quit' to stop): ")
    if user_input == "flip":
        if state == "Light OFF":
            state = "Light ON"
        elif state == "Light ON":
            state = "Light OFF"
        print("Current state:", state)
        print("---")
    elif user_input == "quit":
        print("Program ended.")
        break
    else:
        print("Invalid command")
        print("---")
# Out:
# Current state: Light ON
# ---
# Current state: Light OFF
# ---
# Program ended.
